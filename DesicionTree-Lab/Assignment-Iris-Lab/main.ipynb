# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import confusion_matrix, accuracy_score
from sklearn import tree
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report

# %%
df=pd.read_csv('Iris.csv')
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 0      1            5.1           3.5            1.4           0.2        1
# 1      2            4.9           3.0            1.4           0.2        1
# 2      3            4.7           3.2            1.3           0.2        1
# 3      4            4.6           3.1            1.5           0.2        1
# 4      5            5.0           3.6            1.4           0.2        1
# ..   ...            ...           ...            ...           ...      ...
# 145  146            6.7           3.0            5.2           2.3        2
# 146  147            6.3           2.5            5.0           1.9        2
# 147  148            6.5           3.0            5.2           2.0        2
# 148  149            6.2           3.4            5.4           2.3        2
# 149  150            5.9           3.0            5.1           1.8        2
#
# [150 rows x 6 columns]

# %%
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 0   1            5.1           3.5            1.4           0.2        1
# 1   2            4.9           3.0            1.4           0.2        1
# 2   3            4.7           3.2            1.3           0.2        1
# 3   4            4.6           3.1            1.5           0.2        1
# 4   5            5.0           3.6            1.4           0.2        1

# %%
print(df.isnull().sum())
print(df.duplicated().sum())
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64
# 0

# %%
# 3. Remove duplicates if any
df = df.drop_duplicates()

# 4. Check target column
print(df["Species"].value_counts())

# 5. Encode target label if needed
# If species is already strings, convert to numeric
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df["Species"] = le.fit_transform(df["Species"])

# 6. Split features and target
X = df.drop(columns=["Species"])
y = df["Species"]
# Out:
# Species
# 1    50
# 0    50
# 2    50
# Name: count, dtype: int64

# %%
# 7. Train/test splits
models = {}

for test_size in [0.2, 0.25, 0.3]:
    X_train, X_test, y_train, y_test = train_test_split(
        X, y, test_size=test_size, random_state=42, stratify=y
    )

    classifier_gini = DecisionTreeClassifier(criterion="gini", random_state=42)
    classifier_entropy = DecisionTreeClassifier(criterion="entropy", random_state=42)

    classifier_gini.fit(X_train, y_train)
    classifier_entropy.fit(X_train, y_train)

    models[test_size] = {
        "gini": classifier_gini,
        "entropy": classifier_entropy
    }

    y_pred_gini = classifier_gini.predict(X_test)
    y_pred_entropy = classifier_entropy.predict(X_test)

    print(f"\nTest size = {test_size}")
    print("Gini Accuracy:", accuracy_score(y_test, y_pred_gini))
    print("Entropy Accuracy:", accuracy_score(y_test, y_pred_entropy))

    print("\nGini Classification Report:\n", classification_report(y_test, y_pred_gini))
    print("\nEntropy Classification Report:\n", classification_report(y_test, y_pred_entropy))
# Out:
# Test size = 0.2
# Gini Accuracy: 1.0
# Entropy Accuracy: 1.0
#
# Gini Classification Report:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        10
#            1       1.00      1.00      1.00        10
#            2       1.00      1.00      1.00        10
#
#     accuracy                           1.00        30
#    macro avg       1.00      1.00      1.00        30
# weighted avg       1.00      1.00      1.00        30
#
#
# Entropy Classification Report:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        10
#            1       1.00      1.00      1.00        10
#            2       1.00      1.00      1.00        10
#
#     accuracy                           1.00        30
#    macro avg       1.00      1.00      1.00        30
# weighted avg       1.00      1.00      1.00        30
#
#
# Test size = 0.25
# Gini Accuracy: 1.0
# Entropy Accuracy: 1.0
#
# Gini Classification Report:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        12
#            1       1.00      1.00      1.00        13
#            2       1.00      1.00      1.00        13
#
#     accuracy                           1.00        38
#    macro avg       1.00      1.00      1.00        38
# weighted avg       1.00      1.00      1.00        38
#
#
# Entropy Classification Report:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        12
#            1       1.00      1.00      1.00        13
#            2       1.00      1.00      1.00        13
#
#     accuracy                           1.00        38
#    macro avg       1.00      1.00      1.00        38
# weighted avg       1.00      1.00      1.00        38
#
#
# Test size = 0.3
# Gini Accuracy: 1.0
# Entropy Accuracy: 1.0
#
# Gini Classification Report:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        15
#            1       1.00      1.00      1.00        15
#            2       1.00      1.00      1.00        15
#
#     accuracy                           1.00        45
#    macro avg       1.00      1.00      1.00        45
# weighted avg       1.00      1.00      1.00        45
#
#
# Entropy Classification Report:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        15
#            1       1.00      1.00      1.00        15
#            2       1.00      1.00      1.00        15
#
#     accuracy                           1.00        45
#    macro avg       1.00      1.00      1.00        45
# weighted avg       1.00      1.00      1.00        45

# %%
new_sample = np.array([[5.1, 3.5, 1.4, 0.2]])

for test_size, model_dict in models.items():
    pred_gini = model_dict["gini"].predict(new_sample)
    pred_entropy = model_dict["entropy"].predict(new_sample)

    print(f"\nFor test size = {test_size}")
    print("Gini prediction:", pred_gini)
    print("Entropy prediction:", pred_entropy)
# Out:
# d:\AML-Lab\.venv\Lib\site-packages\sklearn\utils\validation.py:2827: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 4
#       1 new_sample = np.array([[5.1, 3.5, 1.4, 0.2]])
#       2
#       3 for test_size, model_dict in models.items():
# ----> 4     pred_gini = model_dict["gini"].predict(new_sample)
#       5     pred_entropy = model_dict["entropy"].predict(new_sample)
#       6
#       7     print(f"\nFor test size = {test_size}")
#
# File d:\AML-Lab\.venv\Lib\site-packages\sklearn\tree\_classes.py:525, in BaseDecisionTree.predict(self, X, check_input)
#     502 """Predict class or regression value for X.
#     503
#     504 For a classification model, the predicted class for each sample in X is
#    (...)    522     The predicted classes, or the predict values.
#     523 """
#     524 check_is_fitted(self)
# --> 525 X = self._validate_X_predict(X, check_input)
#     526 proba = self.tree_.predict(X)
#     527 n_samples = X.shape[0]
#
# File d:\AML-Lab\.venv\Lib\site-packages\sklearn\tree\_classes.py:484, in BaseDecisionTree._validate_X_predict(self, X, check_input)
#     482 else:
#     483     ensure_all_finite = True
# --> 484 X = validate_data(
#     485     self,
#     486     X,
#     487     dtype=np.float32,
#     488     accept_sparse="csr",
#     489     reset=False,
#     490     ensure_all_finite=ensure_all_finite,
#     491 )
#     492 if issparse(X) and (
#     493     X.indices.dtype != np.intc or X.indptr.dtype != np.intc
#     494 ):
#     495     raise ValueError("No support for np.int64 index based sparse matrices")
#
# File d:\AML-Lab\.venv\Lib\site-packages\sklearn\utils\validation.py:3059, in validate_data(_estimator, X, y, reset, validate_separately, skip_check_array, **check_params)
#    3056     out = X, y
#    3058 if not no_val_X and check_params.get("ensure_2d", True):
# -> 3059     _check_n_features(_estimator, X, reset=reset)
#    3061 return out
#
# File d:\AML-Lab\.venv\Lib\site-packages\sklearn\utils\validation.py:2923, in _check_n_features(estimator, X, reset)
#    2920     return
#    2922 if n_features != estimator.n_features_in_:
# -> 2923     raise ValueError(
#    2924         f"X has {n_features} features, but {estimator.__class__.__name__} "
#    2925         f"is expecting {estimator.n_features_in_} features as input."
#    2926     )
#
# ValueError: X has 4 features, but DecisionTreeClassifier is expecting 5 features as input.
